// %%
%sql
CREATE CATALOG IF NOT EXISTS movies;

// %%
%sql
USE CATALOG movies;

// %%
%sql
CREATE SCHEMA IF NOT EXISTS movies.bronze;
CREATE SCHEMA IF NOT EXISTS movies.silver;
CREATE SCHEMA IF NOT EXISTS movies.gold;
